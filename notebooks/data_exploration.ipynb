# %%
import pandas as pd
import sys
import os
from pathlib import Path


def find_path():
    sys.path.append(os.path.abspath(os.path.join(".","./moto_data/Data")))
    setpath=sys.path
    list_path=list(set([item for item in setpath if "\\moto_data\\Data" in item]))
    if len(list_path)==0:
        print("Data Folder Not Found")
        sys.exit()
    if len(list_path)>1:
        print("More than one data folder found")
        print(list_path)
        sys.exit()
    output_path=list_path[0]
    return output_path

output_path=find_path()
print(output_path.replace("\\", "/"))
file_walk=os.walk(Path(output_path))
res=[]
for (dir_path, dir_names, file_names) in file_walk:
    res.extend(file_names)
print(res)
df_list=[]
for file in file_names:
    df=pd.read_csv(Path(output_path,file))
    df_list.append(df)

master_df=pd.concat(df_list)

print(master_df.info())
# Out:
# C:/Users/kingo/Dropbox/pyProject/moto_data/moto_data/notebooks/moto_data/Data
# []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28588\994062429.py in <cell line: 33>()
#      31     df_list.append(df)
#      32
# ---> 33 master_df=pd.concat(df_list)
#      34
#      35 print(master_df.info())
#
# ~\anaconda3\envs\moto\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\moto\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# ~\anaconda3\envs\moto\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     349
#     350         if len(objs) == 0:
# --> 351             raise ValueError("No objects to concatenate")
#     352
#     353         if keys is None:
#
# ValueError: No objects to concatenate

# %%
# !pip freeze
# Out:
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# attrs==22.1.0
# backcall==0.2.0
# beautifulsoup4==4.11.1
# bleach==5.0.1
# Brotli==1.0.9
# certifi @ file:///C:/b/abs_ac29jvt43w/croot/certifi_1665076682579/work/certifi
# cffi==1.15.1
# charset-normalizer==2.1.1
# click==8.1.3
# colorama==0.4.5
# cycler==0.11.0
# dash==2.6.2
# dash-core-components==2.0.0
# dash-html-components==2.0.0
# dash-table==5.0.0
# debugpy==1.6.2
# decorator==5.1.1
# defusedxml==0.7.1
# entrypoints==0.4
# fastjsonschema==2.16.2
# Flask==2.2.2
# Flask-Compress==1.13
# fonttools==4.37.3
# gunicorn==20.0.4
# idna==3.4
# importlib-metadata==4.12.0
# importlib-resources==5.9.0
# iniconfig==1.1.1
# ipykernel==6.15.1
# ipython==7.34.0
# ipython-genutils==0.2.0
# ipywidgets==8.0.2
# itsdangerous==2.1.2
# jedi==0.18.1
# Jinja2==3.1.2
# joblib==1.2.0
# jsonschema==4.16.0
# jupyter==1.0.0
# jupyter-client==7.3.4
# jupyter-console==6.4.4
# jupyter-core==4.11.1
# jupyterlab-pygments==0.2.2
# jupyterlab-widgets==3.0.3
# kiwisolver==1.4.4
# MarkupSafe==2.1.1
# matplotlib==3.5.3
# matplotlib-inline==0.1.3
# mistune==2.0.4
# nbclient==0.6.8
# nbconvert==7.1.0
# nbformat==5.6.1
# nest-asyncio==1.5.5
# notebook==6.4.12
# numpy==1.21.6
# packaging==21.3
# pandas==1.3.5
# pandocfilters==1.5.0
# parso==0.8.3
# pickleshare==0.7.5
# Pillow==9.2.0
# pkgutil_resolve_name==1.3.10
# plotly==5.10.0
# pluggy==1.0.0
# prometheus-client==0.14.1
# prompt-toolkit==3.0.30
# psutil==5.9.1
# py==1.11.0
# pycparser==2.21
# Pygments==2.12.0
# pyparsing==3.0.9
# pyrsistent==0.18.1
# pytest==7.1.3
# python-dateutil==2.8.2
# pytz==2022.2.1
# pywin32==305
# pywinpty==2.0.9
# pyzmq==23.2.0
# qtconsole==5.3.2
# QtPy==2.2.1
# requests==2.28.1
# scikit-learn==1.0.2
# scipy==1.7.3
# Send2Trash==1.8.0
# six==1.16.0
# sklearn==0.0
# soupsieve==2.3.2.post1
# tenacity==8.1.0
# terminado==0.16.0
# threadpoolctl==3.1.0
# tinycss2==1.1.1
# tomli==2.0.1
# tornado==6.2
# traitlets==5.3.0
# typing_extensions==4.3.0
# urllib3==1.26.12
# wcwidth==0.2.5
# webencodings==0.5.1
# Werkzeug==2.2.2
# widgetsnbextension==4.0.3
# wincertstore==0.2
# zipp==3.8.1
