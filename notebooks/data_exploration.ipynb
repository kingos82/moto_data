# %%
import pandas as pd
import sys
import os
from pathlib import Path


def find_path():
    sys.path.append(os.path.abspath(os.path.join("..","./Data")))
    setpath=sys.path
    list_path=list(set([item for item in setpath if "Data" in item]))
    
    if len(list_path)==0:
        print("Data Folder Not Found")
        sys.exit()
    if len(list_path)>1:
        print("More than one data folder found")
        print(list_path)
        sys.exit()
    output_path=list_path[0]
    return output_path

output_path=find_path()
file_names = []
for name in os.listdir("../Data/"):
    if name.endswith(".csv"):
        file_names.append(name)

df_list=[]
for file in file_names:
    df=pd.read_csv(Path(output_path,file))
    df_list.append(df)

master_df=pd.concat(df_list)

print(master_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 0
# Data columns (total 60 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Unnamed: 0                                                33 non-null     int64
#  1   articleCompleteInfo.articleID                             33 non-null     int64
#  2   articleCompleteInfo.makeName                              33 non-null     object
#  3   articleCompleteInfo.modelName                             33 non-null     object
#  4   articleCompleteInfo.categoryName                          33 non-null     object
#  5   articleCompleteInfo.yearName                              33 non-null     int64
#  6   articleImage.imageName                                    33 non-null     object
#  7   articleImage.link                                         33 non-null     object
#  8   engineAndTransmission.displacementName                    33 non-null     object
#  9   engineAndTransmission.engineTypeName                      33 non-null     object
#  10  engineAndTransmission.powerName                           28 non-null     object
#  11  engineAndTransmission.torqueName                          29 non-null     object
#  12  engineAndTransmission.compressionName                     31 non-null     object
#  13  engineAndTransmission.boreXStrokeName                     32 non-null     object
#  14  engineAndTransmission.valvesPerCylinderName               25 non-null     float64
#  15  engineAndTransmission.fuelSystemName                      32 non-null     object
#  16  engineAndTransmission.ignitionName                        28 non-null     object
#  17  engineAndTransmission.coolingSystemName                   29 non-null     object
#  18  engineAndTransmission.gearboxName                         33 non-null     object
#  19  engineAndTransmission.transmissionTypeFinalDriveName      33 non-null     object
#  20  engineAndTransmission.clutchName                          28 non-null     object
#  21  engineAndTransmission.drivelineName                       19 non-null     object
#  22  engineAndTransmission.fuelConsumptionName                 23 non-null     object
#  23  engineAndTransmission.greenhouseGasesName                 23 non-null     object
#  24  chassisSuspensionBrakesAndWheels.frameTypeName            31 non-null     object
#  25  chassisSuspensionBrakesAndWheels.frontBrakesName          33 non-null     object
#  26  chassisSuspensionBrakesAndWheels.frontBrakesDiameterName  31 non-null     object
#  27  chassisSuspensionBrakesAndWheels.frontSuspensionName      33 non-null     object
#  28  chassisSuspensionBrakesAndWheels.frontTyreName            33 non-null     object
#  29  chassisSuspensionBrakesAndWheels.frontWheelTravelName     27 non-null     object
#  30  chassisSuspensionBrakesAndWheels.rakeName                 28 non-null     object
#  31  chassisSuspensionBrakesAndWheels.rearBrakesName           33 non-null     object
#  32  chassisSuspensionBrakesAndWheels.rearBrakesDiameterName   31 non-null     object
#  33  chassisSuspensionBrakesAndWheels.rearSuspensionName       33 non-null     object
#  34  chassisSuspensionBrakesAndWheels.rearTyreName             33 non-null     object
#  35  chassisSuspensionBrakesAndWheels.rearWheelTravelName      27 non-null     object
#  36  chassisSuspensionBrakesAndWheels.trailName                27 non-null     object
#  37  chassisSuspensionBrakesAndWheels.wheelsName               21 non-null     object
#  38  physicalMeasuresAndCapacities.fuelCapacityName            33 non-null     object
#  39  physicalMeasuresAndCapacities.groundClearanceName         32 non-null     object
#  40  physicalMeasuresAndCapacities.oilCapacityName             19 non-null     object
#  41  physicalMeasuresAndCapacities.overallHeightName           33 non-null     object
#  42  physicalMeasuresAndCapacities.overallLengthName           33 non-null     object
#  43  physicalMeasuresAndCapacities.overallWidthName            33 non-null     object
#  44  physicalMeasuresAndCapacities.seatHeightName              33 non-null     object
#  45  physicalMeasuresAndCapacities.weightInclOilGasEtcName     31 non-null     object
#  46  otherSpecifications.colorOptionsName                      33 non-null     object
#  47  otherSpecifications.factoryWarrantyName                   18 non-null     object
#  48  otherSpecifications.instrumentsName                       22 non-null     object
#  49  otherSpecifications.lightName                             25 non-null     object
#  50  otherSpecifications.starterName                           33 non-null     object
#  51  engineAndTransmission.engineDetailsName                   4 non-null      object
#  52  engineAndTransmission.lubricationSystemName               17 non-null     object
#  53  engineAndTransmission.emissionDetailsName                 16 non-null     object
#  54  otherSpecifications.commentsName                          29 non-null     object
#  55  otherSpecifications.electricalName                        6 non-null      object
#  56  engineAndTransmission.exhaustSystemName                   6 non-null      object
#  57  articleCompleteInfo.priceName                             11 non-null     object
#  58  physicalMeasuresAndCapacities.dryWeightName               2 non-null      object
#  59  physicalMeasuresAndCapacities.reserveFuelCapacityName     1 non-null      object
# dtypes: float64(1), int64(3), object(56)
# memory usage: 15.7+ KB
# None
